# %%
import geopandas as gdp
import numpy as np
import pandas as pd
import networkx as gpd_networkx

# %%
url = ("https://www.stadt-muenster.de/ows/mapserv621/odrichtw_2026serv?SERVICE=WFS&REQUEST=GetCapabilities")

data = gdp.read_file(url)

# %%
features = []
for c in data.columns:
    if data[c].isna().all():
        print(c,"is empty")
    else:
        features.append(c)

new_list = data[features]

# %%
new_list.columns
# Out:
# Index(['GESL', 'GENA', 'GASL', 'BRWZNR', 'GABE', 'GENU', 'GEMA', 'ORTST',
#        'WNUM', 'BRW', 'STAG', 'BRKE', 'PLZ', 'BASBE', 'BASMA', 'YWERT',
#        'XWERT', 'BEZUG', 'ENTW', 'BEIT', 'NUTA', 'ERGNUTA', 'GEZ', 'GFZ',
#        'FLAE', 'GTIE', 'AUFW', 'BEM', 'FREI', 'GFZBV', 'UDOK', 'FARBE', 'HBRW',
#        'HTAG', 'KOR', 'geometry'],
#       dtype='object')

# %%
new_list["KOR"].describe()
# Out:
# count    388.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# Name: KOR, dtype: float64

# %%
new_list["geometry"].unique()
# Out:
# <GeometryArray>
# [<POLYGON ((404875.211 5766524.908, 404882.99 5766524.352, 404888.083 5766524...>,
#  <POLYGON ((401398.501 5764797.35, 401399.426 5764760.542, 401407.08 5764763....>,
#  <POLYGON ((409365.906 5764787.624, 409359.092 5764789.364, 409352.239 576479...>,
#  <POLYGON ((401279.307 5762136.886, 401242.824 5762085.32, 401240.098 5762081...>,
#  <POLYGON ((403378.769 5762147.563, 403389.136 5762124.454, 403406.488 576208...>,
#  <POLYGON ((404020.475 5762212.927, 404021.25 5762175.136, 404022.456 5762155...>,
#  <POLYGON ((405460.887 5750217.94, 405450.899 5750217.17, 405445.592 5750216....>,
#  <POLYGON ((401692.432 5758958.792, 401675.441 5758998.815, 401667.692 575901...>,
#  <POLYGON ((403920.313 5761540.951, 403924.017 5761537.71, 403927.166 5761534...>,
#  <POLYGON ((409223.535 5751263.004, 409222.967 5751262.89, 409221.196 5751271...>,
#  ...
#  <POLYGON ((407808.656 5759163.788, 407759.438 5759169.453, 407720.864 575914...>,
# ...

# %%
a = "LoD2_32_280_5657_1_NW.gml"
gdf = gdp.read_file(a)

print(gdf.head())
# Out:
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyogrio\raw.py:200: RuntimeWarning: Unrecognized geometry type : -2147483648
#   return ogr_read(
#              gml_id creationDate  \
# 0  DENW43AL00001j2X   2025-12-22
# 1  DENW43AL00001j6e   2025-12-22
# 2  DENW43AL0001FUgn   2025-12-22
# 3  DENW43AL0001FUef   2025-12-22
# 4  DENW43AL00001j3w   2025-12-22
#
#                                    informationSystem              name  \
# 0  http://repository.gdi-de.org/schemas/adv/cityg...  DENW43AL00001j2X
# 1  http://repository.gdi-de.org/schemas/adv/cityg...  DENW43AL00001j6e
# 2  http://repository.gdi-de.org/schemas/adv/cityg...  DENW43AL0001FUgn
# 3  http://repository.gdi-de.org/schemas/adv/cityg...  DENW43AL0001FUef
# 4  http://repository.gdi-de.org/schemas/adv/cityg...  DENW43AL00001j3w
#
#   Gemeindeschluessel DatenquelleDachhoehe  Geometrietyp2DReferenz  \
# ...

# %%
from anthropic import Anthropic

# Der Client sucht automatisch nach der Umgebungsvariablen ANTHROPIC_API_KEY
client = Anthropic(api_key="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")

message = client.messages.create(
    model="claude-opus-4-6",
    max_tokens=1024,
    messages=[{"role": "user", "content": "Wo erhalte ich Daten zu allen Grundstücken in Münster? Das beinhaltet Gebäude auf diesem Grundstück, "
    "Größe und Anzahl an Etagen."}]
)
print(message.content[0].text)
# Out:
# # Grundstücksdaten in Münster
#
# Es gibt mehrere Quellen, über die du an umfassende Grundstücksdaten in Münster gelangen kannst:
#
# ## Offizielle / Behördliche Quellen
#
# ### 1. **Katasteramt / Vermessungs- und Katasteramt Münster**
# - Flurstücksdaten, Grundstücksgrenzen, Flächengrößen
# - Kontakt über die **Stadt Münster** oder den **Kreis**
# - [stadt-muenster.de](https://www.stadt-muenster.de)
#
# ### 2. **ALKIS (Amtliches Liegenschaftskatasterinformationssystem)**
# - Enthält Flurstücke, Gebäude, Nutzungsarten
# - Zugang über **Geobasis NRW / Bezirksregierung Köln**
# - [www.geobasis.nrw.de](https://www.geobasis.nrw.de)
#
# ### 3. **Grundbuchamt (Amtsgericht Münster)**
# - Eigentumsverhältnisse, Belastungen
# - Nur mit berechtigtem Interesse einsehbar
#
# ### 4. **Bauordnungsamt Münster**
# - Informationen zu Gebäuden, Geschosszahlen, Baugenehmigungen
#
# ## Open Data / Geoportale
#
# ### 5. **Geoportal Münster / NRW**
# ...

# %%
alkis = gdp.read_file("https://www.stadt-muenster.de/ows/mapserv706/odalkisserv?REQUEST=GetFeature&SERVICE=WFS&VERSION=1.1.0&TYPENAME=ms:flurstuecke&EXCEPTIONS=XML&MAXFEATURES=150000&suche=and%20gmk_gmn%20=%20%275006%27%20and%20fln%20=%20%27006%27")

bodenrichtwerte = gdp.read_file("https://www.stadt-muenster.de/ows/mapserv621/odrichtw_2026serv?SERVICE=WFS&REQUEST=GetCapabilities")

buildings = gdp.read_file("https://www.stadt-muenster.de/ows/mapserv706/odalkisserv?REQUEST=GetFeature&SERVICE=WFS&VERSION=1.0.0&TYPENAME=ms:gebaeude&EXCEPTIONS=XML&MAXFEATURES=150000&suche=")

building_plans = gdp.read_file("https://geo.stadt-muenster.de/mapserv/bplan_serv?REQUEST=GetFeature&SERVICE=WFS&VERSION=2.0.0&TYPENAME=ms:bplan2&EXCEPTIONS=XML&MAXFEATURES=10000")

# %%
alkis

# %%
buildings_munster
# Out:
#        gml_id     gid   modellart  grf   gfk            funktion  \
# 0        None   15354  DLKM.NWABK   27  2460  Gebäude zum Parken
# 1        None   15355  DLKM.NWABK   30  2460  Gebäude zum Parken
# 2        None   15778  DLKM.NWABK   15  2460  Gebäude zum Parken
# 3        None   15356  DLKM.NWABK  216  2460  Gebäude zum Parken
# 4        None   15357  DLKM.NWABK   65  1000     Wohngebäude (G)
# ...       ...     ...         ...  ...   ...                 ...
# 107756   None  112143  DLKM.NWABK  224  1000     Wohngebäude (G)
# 107757   None  112144  DLKM.NWABK   63  2460  Gebäude zum Parken
# 107758   None  112119  DLKM.NWABK  352  1000     Wohngebäude (G)
# 107759   None  112120  DLKM.NWABK   87  3072           Feuerwehr
# 107760   None  112130  DLKM.NWABK   69  1000     Wohngebäude (G)
#
#                                                  geometry
# 0       POLYGON ((400943.744 5761621.422, 400945.783 5...
# 1       POLYGON ((408077.444 5751522.504, 408082.379 5...
# ...

# %%
buildings_munster.geometry.area
# Out:
# 0          27.348013
# 1          30.223373
# 2          15.116418
# 3         215.668971
# 4          65.276848
#              ...
# 107756    223.882944
# 107757     62.910711
# 107758    352.014144
# 107759     86.766924
# 107760     68.922314
# Length: 107761, dtype: float64

# %%
joined = gdp.sjoin(
    buildings_munster,
    alkis,
    predicate="within"
)

print(f"Gebäude: {len(buildings_munster)}")
print(f"Zugeordnete Gebäude: {len(joined)}")
# Out:
# Gebäude: 107761
# Zugeordnete Gebäude: 35
# C:\Users\User\AppData\Local\Temp\ipykernel_12312\39231339.py:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:25832
#
#   joined = gdp.sjoin(

# %%
joined.shape
# Out:
# (37, 19)

# %%
import osmnx as ox

buildings = ox.features_from_place(
    "Münster, Germany",
    tags={"building": True}
)

buildings[
    "building:levels"
]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import osmnx as ox
#       3 buildings = ox.features_from_place(
#       4     "Münster, Germany",
#       5     tags={"building": True}
#       6 )
#       8 buildings[
#       9     "building:levels"
#      10 ]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\osmnx\__init__.py:20
#      18 from . import bearing as bearing
#      19 from . import convert as convert
# ---> 20 from . import distance as distance
#      21 from . import elevation as elevation
#      22 from . import features as features
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\osmnx\distance.py:22
# ...
